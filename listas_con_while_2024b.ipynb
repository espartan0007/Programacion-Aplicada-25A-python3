# %% [markdown]
# <a href="https://colab.research.google.com/github/espartan0007/Programacion-Aplicada-25A-python3/blob/main/listas_con_while_2024b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#lista=[]# lista vacia
lista=[1,2,3,4,3.1416] # defini info en la lista

i=0 # def una var que es una posicion de la lista
print(lista[i])  # imprimiendo posicion 4 de la lista
lista[i]=99
print(lista[i])  # imprimiendo posicion 4 de la lista

print(lista) # imprimiendo la lista

lista[0]=12
lista[1]=13
lista[2]=14
lista[3]=15
lista[4]=16
# Out:
# 1
# 99
# [99, 2, 3, 4, 3.1416]

# %%
while True:
  print(" infinito veces")
  print(" infinito veces1")
  print(" infinito veces2")
  print(" infinito veces3")
  print(" infinito veces4")
  print(" infinito veces5")

# %%
c=0# importante valor de inicio del contador

while c <5: #True
  print(c)
  #print("Hola")
  c=c+1
  #print("\n")

print("valor final",c)
# Out:
# 0
# 1
# 2
# 3
# 4
# valor final 5

# %% [markdown]
# Diseñe y codifique en python 3.x unalgoritmo que sobre-escriba los valores de una lista 5 elementos con valores aleatorios.Imprir al final la lista completa.

# %%
import random as rn
lista=[1,2,3,4,3.1416] # defini info en la lista

c=0

while c <5:
  #print(c)
  lista[c]=rn.randint(80,100)
  c=c+1


print("valor final",c,"\n")
print(lista)
# Out:
# valor final 5
#
# [92, 90, 90, 87, 87]

# %%
import random as rn
lista=[1,2,3,4,3.1416] # defini info en la lista

c=0

while c <5:
  print("Escribe la calificacions no. ",c+1)
  cal=int(input("Calificaciones de 0-99") )
  lista[c]=cal
  c=c+1

print("valor final",c,"\n")
print(lista)
# Out:
# Escribe la calificacions no.  1
# Calificaciones de 0-9978
# Escribe la calificacions no.  2
# Calificaciones de 0-9966
# Escribe la calificacions no.  3
# Calificaciones de 0-9989
# Escribe la calificacions no.  4
# Calificaciones de 0-9990
# Escribe la calificacions no.  5
# Calificaciones de 0-99100
# valor final 5
#
# [78, 66, 89, 90, 100]

# %%
lista=[78, 66, 89, 90, 100]
i=0# importante valor de inicio

while i <=4: #True
  #print(i)
  #print("El valor de la lista en la posicion ",i," es ",lista[i])
  print(lista[i])
  i=i+1 # Contador
  #print("\n")

#print("valor final",i)
import random as rn
lista=[1,2,3,4,3.1416] # defini info en la lista

c=0

while c <5:
  print("Escribe la calificacions no. ",c+1)
  cal=int(input("Calificaciones de 0-99") )
  lista[c]=cal
  c=c+1

print("valor final",c,"\n")
print(lista)
# Out:
# 78
# 66
# 89
# 90
# 100

# %%
#####################################################
lista=[0,0,0,0,0,0]
i=0# importante valor de inicio

while i <=5: #True
  print("Escribe la calificacion numero:",i)
  cal=float(input("Calificaciones de 0-99"))
  lista[i]=cal
  i=i+1 # Contador
print("\nLa lista es",lista)
print("La sumatoria es:",sum(lista))
print("Promedio",sum(lista)/6)
# Out:
# Escribe la calificacion numero: 0
# Calificaciones de 0-9999
# Escribe la calificacion numero: 1
# Calificaciones de 0-9999
# Escribe la calificacion numero: 2
# Calificaciones de 0-9999
# Escribe la calificacion numero: 3
# Calificaciones de 0-9999
# Escribe la calificacion numero: 4
# Calificaciones de 0-9999
# Escribe la calificacion numero: 5
# Calificaciones de 0-9999
#
# La lista es [99.0, 99.0, 99.0, 99.0, 99.0, 99.0]
# La sumatoria es: 594.0
# Promedio 99.0

# %%
#####################################################
lista=[0,0,0]

i=0# importante valor de inicio
n=len(lista)
while i <n: #True
  print("Escribe la calificacion numero:",i)
  cal=float(input("Calificaciones de 0-99"))
  lista[i]=cal
  i=i+1 # Contador
print("\nLa lista es",lista)
print("La sumatoria es:",sum(lista))
print("Promedio",sum(lista)/n)
# Out:
# Escribe la calificacion numero: 0
# Calificaciones de 0-9933
# Escribe la calificacion numero: 1
# Calificaciones de 0-9944
# Escribe la calificacion numero: 2
# Calificaciones de 0-9955
#
# La lista es [33.0, 44.0, 55.0]
# La sumatoria es: 132.0
# Promedio 44.0

# %%
n=5 # define la longitud de todo(lista, ELogica y div de promedio)
lista=[None]*n

print(lista)
# Out:
# [None, None, None, None, None]

# %%
n=3 # define la longitud de todo(lista, ELogica y div de promedio)
lista=[None]*n

print(lista)

i=0# importante valor de inicio

while i <n: #True
  print("Escribe la calificacion numero:",i)
  cal=float(input("Calificaciones de 0-99"))
  lista[i]=cal
  i=i+1 # Contador
print("\nLa lista es ",lista)
print("La sumatoria es :",sum(lista))
print("Promedio ",sum(lista)/n)
# Out:
# [None, None, None]
# Escribe la calificacion numero: 0
# Calificaciones de 0-9945
# Escribe la calificacion numero: 1
# Calificaciones de 0-9956
# Escribe la calificacion numero: 2
# Calificaciones de 0-9988
#
# La lista es [45.0, 56.0, 88.0]
# La sumatoria es: 189.0
# Promedio 63.0

# %%
lista=[]
i=0# importante valor de inicio

while i <=3: #True
  print("Escribe la calificacion numero:",i)
  cal=float(input("Calificaciones de 0-99"))
  lista.append(cal)
  i=i+1 # Contador
  print("La lista es",lista)

print("\nLa lista es ",lista)
print("La sumatoria es:",sum(lista))
print("Promedio ",sum(lista)/i)

# %%
lista=[]

n=int(input("Cuantas calificaciones necesitas capturar?? "))
i=0# importante valor de inicio

while i <n: #True
  print("Escribe la calificacion numero:",i)
  cal=float(input("Calificaciones de 0-99"))
  lista.append(cal)
  i=i+1 # Contador
  print("La lista es",lista)

print("\nLa lista es",lista)
print("La sumatoria es:",sum(lista))
print("Promedio",sum(lista)/n)
# Out:
# Cuantas calificaciones necesitas capturar?? 3
# Escribe la calificacion numero: 0
# Calificaciones de 0-9999
# La lista es [99.0]
# Escribe la calificacion numero: 1
# Calificaciones de 0-9988
# La lista es [99.0, 88.0]
# Escribe la calificacion numero: 2
# Calificaciones de 0-99100
# La lista es [99.0, 88.0, 100.0]
#
# La lista es [99.0, 88.0, 100.0]
# La sumatoria es: 287.0
# Promedio 95.66666666666667

# %%
lista=[]
materia=[]

n=int(input("Cuantas calificaciones necesitas capturar?? "))
i=0# importante valor de inicio

while i <n: #
  name=input("Nombre de la materia: ")
  materia.append(name)
  print("\n Escribe la calificacion numero: ",i)
  cal=float(input("Calificaciones de 0-99"))
  lista.append(cal)
  i=i+1 # Contador
print("\n")
i=0

while i <n: #While de impresion
  print("Tu calificaciones de",materia[i], "es",lista[i])
  print("\n")
  i=i+1 # Contador


#print("\nLa las materias son",materia)
#print("\nLa las calificaciones osn",lista)

print("Promedio",sum(lista)/n)
# Out:
# Cuantas calificaciones necesitas capturar?? 3
# Nombre de la materia: Mecanica I
#
#  Escribe la calificacion numero: 0
# Calificaciones de 0-9999
# Nombre de la materia: Programacion aplicada
#
#  Escribe la calificacion numero: 1
# Calificaciones de 0-9990
# Nombre de la materia: Fisica
#
#  Escribe la calificacion numero: 2
# Calificaciones de 0-9978
#
#
# Tu calificaciones de Mecanica I es 99.0
#
#
# Tu calificaciones de Programacion aplicada es 90.0
#
#
# Tu calificaciones de Fisica es 78.0
#
#
# Promedio 89.0

# %%
li=["Fisica","Mecanica"]
print(li[0])
# Out:
# Fisica

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Diseñe y codifique un algoritmo para el calculo de MG(Media Geometrica) para datos no agrupados
# en la cual los datos vienen capturados por el programador, imprimir todos los datos de entrada e imprimir
#el valor de la media geométrica
import math
datos=[1.45, 2.4545, 7.1231, 68.99, 45.33]
frec=[0.23,0.34,0.1,0.32,0.45]
# Que valor se imprime con el siguiente comando print( datos[3] ) ???
n=len(datos)
# investiga que hace len() en python ??
Sigma=0
i=0
while i<n:
  Sigma=Sigma+math.log(datos[i])
  i+=1 # investiga que hace esta instruccion ??
#Cual es el ultimo valor de i  ??????????
j=0
print("Los valores de entrada son")
while j<n:
  print("\n Valor numero ",j,"es",datos[j])
  j=j+1
#El While con i y j hacen recorridos numericos diferentes ??
print("El resultado dela media geometrica es",Sigma/n)
#Donde se guardo el resultado de la MG ???

#q=[mathlog(datos[i]*frec[i]) for i in range(n)]
# Out:
# Los valores de entrada son
#
#  Valor numero  0 es 1.45
#
#  Valor numero  1 es 2.4545
#
#  Valor numero  2 es 7.1231
#
#  Valor numero  3 es 68.99
#
#  Valor numero  4 es 45.33
# El resultado dela media geometrica es 2.2561520572770797

# %%
import math
datos=[1.45, 2.4545, 7.1231, 68.99, 45.33]
frec=[0.23,0.34,0.1,0.32,0.45]

n=len(datos)
q=[math.log(datos[i]*frec[i]) for i in range(n)]
print(q)
# Out:
# [-1.0981124136264586, -0.18088658685595985, -0.33924206906787596, 3.0945272833696524, 3.0154613687349863]

# %%
#Diseñe y codifique un algoritmo para el calculo de MG(Media Geometrica 2) para datos agrupados
# en la cual los datos y el Fi vienen capturados por el programador, imprimir todos los datos de entrada e imprimir
#el valor de la media geométrica 2.
import math
datos=[1.45, 2.4545, 7.1231, 68.99, 45.33]
frec=[0.23,0.34,0.1,0.32,0.45]

# %%
emails=[]
passw=[]

i=0
while i<2:
  uemail=input("email")
  pssw=input("passw")
  emails.append(uemail)
  passw.append(pssw)
  i+=1

print(emails,passw)
# Out:
# email@gmail.com
# passw3849384
# email@hotmail.com
# passw8982
# ['@gmail.com', '@hotmail.com'] ['3849384', '8982']
